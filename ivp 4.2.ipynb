# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
from PIL import Image, ImageOps
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# %%
from tqdm import tqdm

files = os.listdir('UTKFace')

# %%
import cv2
images = []
genders = []

for i in tqdm(files):
    split = i.split('_')
    genders.append(np.array(int(split[1])))
    p = 'UTKFace'+'/'+i
    img = cv2.imread(p)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    images.append(np.array(img))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 23604/23604 [00:28<00:00, 814.07it/s]

# %%
import matplotlib.pyplot as plt
print(genders[1500])
plt.imshow(images[1500])
# Out:
# 1

# %%
images = np.array(images)
gender = np.array(genders,np.uint64)

# %% [markdown]
# ### Split Data

# %%
x_train_gender,x_test_gender,y_train_gender,y_test_gender = train_test_split(images,gender,random_state=42)

# %%
x_train_gender.shape
# Out:
# (17703, 200, 200, 3)

# %% [markdown]
# ### Define Gender Model using ReLU

# %%
genmodel = Sequential()
genmodel.add(Conv2D(32, (3,3), activation='relu', input_shape=(200, 200, 3)))
genmodel.add(MaxPooling2D((2,2)))

genmodel.add(Conv2D(64, (3,3), activation='relu'))
genmodel.add(MaxPooling2D((2,2)))

genmodel.add(Conv2D(128, (3,3), activation='relu'))
genmodel.add(MaxPooling2D((2,2)))

genmodel.add(Flatten())

genmodel.add(Dense(64, activation='relu'))
genmodel.add(Dropout(0.5))

genmodel.add(Dense(1, activation='sigmoid',name='Gender_OP'))

# %%
genmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 67712)             0
#
#  dense (Dense)               (None, 64)                4333632
#
#  dropout (Dropout)           (None, 64)                0
#
#  Gender_OP (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 4,426,945
# Trainable params: 4,426,945
# Non-trainable params: 0
# _________________________________________________________________

# %%
genmodel.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
datagen = ImageDataGenerator(rescale=1./255., width_shift_range = 0.1, height_shift_range = 0.1, horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale=1./255)

train2 = datagen.flow(x_train_gender, y_train_gender, batch_size=64)

test2 = test_datagen.flow(x_test_gender, y_test_gender,batch_size=64)

# %%
history3 = genmodel.fit(train2, epochs=50, shuffle=True, validation_data=test2)
# Out:
# Epoch 1/50
# 277/277 [==============================] - 563s 2s/step - loss: 0.5653 - accuracy: 0.7085 - val_loss: 0.4831 - val_accuracy: 0.7702
# Epoch 2/50
# 277/277 [==============================] - 529s 2s/step - loss: 0.4861 - accuracy: 0.7695 - val_loss: 0.4162 - val_accuracy: 0.8049
# Epoch 3/50
# 277/277 [==============================] - 529s 2s/step - loss: 0.4483 - accuracy: 0.7920 - val_loss: 0.3817 - val_accuracy: 0.8277
# Epoch 4/50
# 277/277 [==============================] - 530s 2s/step - loss: 0.4299 - accuracy: 0.8007 - val_loss: 0.3701 - val_accuracy: 0.8373
# Epoch 5/50
# 277/277 [==============================] - 535s 2s/step - loss: 0.4159 - accuracy: 0.8113 - val_loss: 0.3468 - val_accuracy: 0.8453
# Epoch 6/50
# 277/277 [==============================] - 607s 2s/step - loss: 0.3903 - accuracy: 0.8224 - val_loss: 0.3315 - val_accuracy: 0.8541
# Epoch 7/50
# 277/277 [==============================] - 1003s 4s/step - loss: 0.3720 - accuracy: 0.8319 - val_loss: 0.3118 - val_accuracy: 0.8666
# Epoch 8/50
# 277/277 [==============================] - 486s 2s/step - loss: 0.3577 - accuracy: 0.8374 - val_loss: 0.2991 - val_accuracy: 0.8680
# Epoch 9/50
# 277/277 [==============================] - 439s 2s/step - loss: 0.3467 - accuracy: 0.8472 - val_loss: 0.3026 - val_accuracy: 0.8673
# Epoch 10/50
# 277/277 [==============================] - 411s 1s/step - loss: 0.3405 - accuracy: 0.8463 - val_loss: 0.2915 - val_accuracy: 0.8704
# Epoch 11/50
# Epoch 34/50
# 277/277 [==============================] - 353s 1s/step - loss: 0.2553 - accuracy: 0.8929 - val_loss: 0.2358 - val_accuracy: 0.9002
# Epoch 35/50
# 277/277 [==============================] - 350s 1s/step - loss: 0.2522 - accuracy: 0.8940 - val_loss: 0.2393 - val_accuracy: 0.8985
# Epoch 36/50
# 277/277 [==============================] - 351s 1s/step - loss: 0.2475 - accuracy: 0.8927 - val_loss: 0.2392 - val_accuracy: 0.9054
# Epoch 37/50
# 277/277 [==============================] - 352s 1s/step - loss: 0.2470 - accuracy: 0.8934 - val_loss: 0.2407 - val_accuracy: 0.8998
# Epoch 38/50
# 277/277 [==============================] - 374s 1s/step - loss: 0.2458 - accuracy: 0.8975 - val_loss: 0.2427 - val_accuracy: 0.9010
# Epoch 39/50
# 277/277 [==============================] - 417s 2s/step - loss: 0.2431 - accuracy: 0.8982 - val_loss: 0.2309 - val_accuracy: 0.9066
# Epoch 40/50
# 277/277 [==============================] - 447s 2s/step - loss: 0.2436 - accuracy: 0.8989 - val_loss: 0.2315 - val_accuracy: 0.9048
# Epoch 41/50
# 277/277 [==============================] - 427s 2s/step - loss: 0.2383 - accuracy: 0.8983 - val_loss: 0.2472 - val_accuracy: 0.9022
# Epoch 42/50
# 277/277 [==============================] - 448s 2s/step - loss: 0.2367 - accuracy: 0.8983 - val_loss: 0.2338 - val_accuracy: 0.9021
# Epoch 43/50
# 277/277 [==============================] - 409s 1s/step - loss: 0.2328 - accuracy: 0.9005 - val_loss: 0.2384 - val_accuracy: 0.8983
# Epoch 44/50
# 277/277 [==============================] - 407s 1s/step - loss: 0.2359 - accuracy: 0.8993 - val_loss: 0.2378 - val_accuracy: 0.8992
# Epoch 45/50
# 277/277 [==============================] - 399s 1s/step - loss: 0.2368 - accuracy: 0.9011 - val_loss: 0.2438 - val_accuracy: 0.9009
# Epoch 46/50
# 277/277 [==============================] - 395s 1s/step - loss: 0.2350 - accuracy: 0.9033 - val_loss: 0.2382 - val_accuracy: 0.9014
# Epoch 47/50
# 277/277 [==============================] - 404s 1s/step - loss: 0.2333 - accuracy: 0.9024 - val_loss: 0.2351 - val_accuracy: 0.9019
# Epoch 48/50
# 277/277 [==============================] - 404s 1s/step - loss: 0.2320 - accuracy: 0.9050 - val_loss: 0.2445 - val_accuracy: 0.8995
# Epoch 49/50
# 277/277 [==============================] - 411s 1s/step - loss: 0.2320 - accuracy: 0.9014 - val_loss: 0.2285 - val_accuracy: 0.9029
# Epoch 50/50
# 277/277 [==============================] - 381s 1s/step - loss: 0.2313 - accuracy: 0.9036 - val_loss: 0.2351 - val_accuracy: 0.9010

# %%
genmodel.save('genmodel_relu.h5')

# %%
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('Accuracy')
plt.legend(['Train','Test'])
plt.show()

# %%
img = cv2.imread('aditya.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img = np.array(img)
plt.imshow(img)
img = cv2.resize(img,(200,200))
img = img/255
img = img.reshape(-1, 200, 200, 3)
gender = genmodel.predict(img)
print("Gender:",round(gender[0][0]))
# Out:
# Gender: 0

# %%
img = cv2.imread('jennifer.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img = np.array(img)
plt.imshow(img)
img = cv2.resize(img,(200,200))
img = img/255
img = img.reshape(-1, 200, 200, 3)
gender = genmodel.predict(img)
print("Gender:",round(gender[0][0]))
# Out:
# Gender: 1

# %%
i = images[1500]
plt.imshow(i)
i = i/255
i = i.reshape(-1, 200, 200, 3)
pred = genmodel.predict(i)[0][0]
round(pred)
# Out:
# 1
